# %%
import sys
sys.path.append('dataloader')
from dataloader.main_dataset import MainDataset
import pickle
with open('new_small_main_dataset.pkl', 'rb') as f:
    dataset = pickle.load(f)

print(len(dataset))
# Out:
# 57

# %%
import importlib
import web_utils
importlib.reload(web_utils)

index = 10
ct_img1=dataset[index]["item1"]["ct"].numpy().squeeze()
ct_img2=dataset[index]["item2"]["ct"].numpy().squeeze()
masks = dataset[index]["item1"]["masks"].numpy().squeeze()
masks2 = dataset[index]["item2"]["masks"].numpy().squeeze()
z_pos = dataset[index]["item1"]["z_position"]
pixel_size_mm = dataset[index]["item1"]['pixel_size_mm']

deformed_planned_ct, transformed_masks, t_vector = web_utils.transform_ct(
    ct_img1, masks, ct_img2, masks2, z_pos, pixel_size_mm, plot=True)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.00020755..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.00012834002..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.00011786777..1.0].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.00012834002..1.0].
# Translation vector: (-1.0557861300512352, 0.4528533155697694) mm
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 13
#      10 z_pos = dataset[index]["item1"]["z_position"]
#      11 pixel_size_mm = dataset[index]["item1"]['pixel_size_mm']
# ...

# %%
transformed_masks.shape
# Out:
# (3, 512, 512)

# %%
index = 45

img=dataset[index]["item1"]["ct"].numpy().squeeze()
gtv = dataset[index]["item1"]["masks"][2].numpy().squeeze()

gtv = gtv
# display image
import matplotlib.pyplot as plt
vis_img = img.copy()
# overwrite areas where gtv is 1
vis_img[gtv == 1] = img.max()

print(dataset[index]["item1"]["rs_uid"])
print(dataset[index]["item1"]["z_position"])

plt.imshow(vis_img, cmap='gray');
# Out:
# 1.2.246.352.221.46272062591570509005209218152822185346
# -246.0

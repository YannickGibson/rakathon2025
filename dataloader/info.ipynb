# %%
# Displaying CT
import pydicom
ds = pydicom.dcmread("data/SAMPLE_001/CT.1.2.246.352.221.50911002929711127858269804207128222.dcm")
print(ds)
# Out:
# Dataset.file_meta -------------------------------
# (0002,0000) File Meta Information Group Length  UL: 182
# (0002,0001) File Meta Information Version       OB: b'\x00\x01'
# (0002,0002) Media Storage SOP Class UID         UI: CT Image Storage
# (0002,0003) Media Storage SOP Instance UID      UI: 1.2.246.352.221.50911002929711127858269804207128222
# (0002,0010) Transfer Syntax UID                 UI: Implicit VR Little Endian
# (0002,0012) Implementation Class UID            UI: 1.2.246.352.70.2.1.160.3
# (0002,0013) Implementation Version Name         SH: 'DCIE 2.2'
# -------------------------------------------------
# (0008,0005) Specific Character Set              CS: 'ISO_IR 192'
# (0008,0008) Image Type                          CS: ['ORIGINAL', 'PRIMARY', 'AXIAL']
# (0008,0012) Instance Creation Date              DA: '20250408'
# (0008,0013) Instance Creation Time              TM: '105413'
# (0008,0016) SOP Class UID                       UI: CT Image Storage
# ...

# %%
# Displaying RS
l = \
"""\
RS.1.2.246.352.221.46272062591570509005209218152822185346.dcm
RS.1.2.246.352.221.46437063671244739784259943870025417870.dcm
RS.1.2.246.352.221.46648924540845111847267152667592345525.dcm
RS.1.2.246.352.221.47996326910951877673095770036963727013.dcm
RS.1.2.246.352.221.50083158019145869357603366655015332242.dcm
RS.1.2.246.352.221.52109299620156711212340860330565438396.dcm
RS.1.2.246.352.221.52903467354308756464807804479012111033.dcm
RS.1.2.246.352.221.53086809173815688567595866456863246500.dcm
RS.1.2.246.352.221.53187058454369481041802669984887751089.dcm
RS.1.2.246.352.221.53270201326814448823512078937670475157.dcm
RS.1.2.246.352.221.53650830509301879903201092234093239207.dcm
RS.1.2.246.352.221.53654805566658963316920417933225950611.dcm
RS.1.2.246.352.221.54208629386503730776063647916545546147.dcm
RS.1.2.246.352.221.54282847437012967561449415280766186922.dcm
RS.1.2.246.352.221.54903236567887871684460111916801263798.dcm
RS.1.2.246.352.221.55753320431045639278301833061808483991.dcm
RS.1.2.246.352.221.56777467771220501527428817917418818748.dcm
RS.1.2.246.352.221.57210835703108360957312090375810850181.dcm
RS.1.2.246.352.221.465349918646845253017819089048979885241.dcm
RS.1.2.246.352.221.474069323621439861613904667800073459614.dcm
RS.1.2.246.352.221.481174969307759734717884954844423716500.dcm"""

l = l.split("\n")
s = l[0]
path = f"data/SAMPLE_001/{s}"
print(path)
import pydicom
ds = pydicom.dcmread(path)
print(ds.dir("sequence"))
#print(ds)
# Out:
# data/SAMPLE_001/RS.1.2.246.352.221.46272062591570509005209218152822185346.dcm
# ['CodingSchemeIdentificationSequence', 'ContextGroupIdentificationSequence', 'DeidentificationMethodCodeSequence', 'MappingResourceIdentificationSequence', 'ROIContourSequence', 'RTROIObservationsSequence', 'ReferencedFrameOfReferenceSequence', 'StructureSetROISequence']

# %%
dates_property_names = ds.dir("date")

for name in dates_property_names:
    print(name, getattr(ds, name))
# Out:
# InstanceCreationDate 20250408
# PatientBirthDate
# ReviewDate 20230616
# StructureSetDate 20230616
# StudyDate 20230605

# %%
print(ds.ReferencedFrameOfReferenceSequence[0].RTReferencedStudySequence[0].RTReferencedSeriesSequence[0].ContourImageSequence[0].ReferencedSOPInstanceUID)

ui = ds.ReferencedFrameOfReferenceSequence[0].RTReferencedStudySequence[0].RTReferencedSeriesSequence[0].ContourImageSequence[0].ReferencedSOPInstanceUID
print(ds.ReferencedFrameOfReferenceSequence[0].RTReferencedStudySequence[0].RTReferencedSeriesSequence[0].ContourImageSequence[0].dir(""))
print(len(ds.ReferencedFrameOfReferenceSequence[0].RTReferencedStudySequence[0].RTReferencedSeriesSequence[0].ContourImageSequence))
print(ds.ReferencedFrameOfReferenceSequence[0].RTReferencedStudySequence)
# Out:
# 1.2.246.352.221.573116050216672241516819602084755302536
# ['ReferencedSOPClassUID', 'ReferencedSOPInstanceUID']
# 196
# [(0008,1150) Referenced SOP Class UID            UI: RT Structure Set Storage
# (0008,1155) Referenced SOP Instance UID         UI: 1.2.246.352.221.570003398414459193616950218784466668220
# (3006,0014)  RT Referenced Series Sequence  1 item(s) ----
#    (0020,000E) Series Instance UID                 UI: 1.2.246.352.221.532801171531264892515869844040626054538
#    (3006,0016)  Contour Image Sequence  196 item(s) ----
#       (0008,1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008,1155) Referenced SOP Instance UID         UI: 1.2.246.352.221.573116050216672241516819602084755302536
#       ---------
#       (0008,1150) Referenced SOP Class UID            UI: CT Image Storage
#       (0008,1155) Referenced SOP Instance UID         UI: 1.2.246.352.221.57508053654037905758625300225104422312
#       ---------
# ...

# %%
# check if file exists
import os
path = f"data/SAMPLE_001/CT.{ui}.dcm"
print(os.path.exists(path))
# Out:
# True
